# %%
import joblib

model = joblib.load('hospitalization_model.pkl')

# %%
import pandas as pd
import joblib
from sklearn.metrics import classification_report

model = joblib.load('hospitalization_model.pkl')
feature_columns = joblib.load('feature_columns.pkl')

# Load your test data
test_data = pd.read_csv('sample_test_data.csv')

# Separate features and target
X_test = test_data.drop(columns=['hospitalized'])
y_test = test_data['hospitalized']

# Fill missing columns in test data with False or 0 (depending on your feature type)
for col in feature_columns:
    if col not in X_test.columns:
        X_test[col] = False  # or 0 if numeric

# Reorder columns to match training
X_test = X_test[feature_columns]

# Predict using loaded model
y_pred = model.predict(X_test)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
# /tmp/ipykernel_186255/146983438.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = False  # or 0 if numeric
# /tmp/ipykernel_186255/146983438.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test[col] = False  # or 0 if numeric
# ...

# %%
from sklearn.metrics import accuracy_score


accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")  # prints accuracy as decimal (e.g., 0.85)
# Out:
# Accuracy: 0.6250
